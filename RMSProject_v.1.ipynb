# %%
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
import sys

from sklearn import (
    linear_model, metrics, neural_network, pipeline, preprocessing, model_selection
)

import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_row', 1000)

# %%
data = pd.read_csv('UCF_TLDClustering.txt', sep="\|\|", engine='python')

# %%
data.columns = ["StoreID", "StoreGroup", "PeriodID", "TicketID", "ItemName", "ItemCategory", "Qty", "Sales", "Modifier"]

# %%
data.head()
# Out:
#          StoreID StoreGroup    PeriodID  TicketID  ItemName  ItemCategory  \
# count   12811321   12811321    12811321  12811321  12811321      12811321
# unique        90          7         365       498       397             7
# top         202{        }F{  }20190302{      }32{   }Apple{  }Automobile{
# freq      298687    2053989       54210    100581   1313144       5724853
#
#              Qty     Sales  Modifier
# count   12811321  12811321  12811321
# unique        91      1203         2
# top          }1{       }0{        }0
# freq    10850445   1851939  10959386

# %%
data.describe()
# Out:
#          StoreID StoreGroup    PeriodID  TicketID  ItemName  ItemCategory  \
# count   12811321   12811321    12811321  12811321  12811321      12811321
# unique        90          7         365       498       397             7
# top         202{        }F{  }20190302{      }32{   }Apple{  }Automobile{
# freq      298687    2053989       54210    100581   1313144       5724853
#
#              Qty     Sales  Modifier
# count   12811321  12811321  12811321
# unique        91      1203         2
# top          }1{       }0{        }0
# freq    10850445   1851939  10959386

# %%
df = pd.DataFrame(data)

# %%
df = df.applymap(lambda x: x.replace('{', ''))

# %%
df = df.applymap(lambda x: x.replace('}', ''))

# %%
df.head()
# Out:
#   StoreID StoreGroup  PeriodID TicketID        ItemName ItemCategory Qty  \
# 0       1          A  20180801        1      Chevy Ajax   Automobile   1
# 1       1          A  20180801        2     Chevy Spark   Automobile   1
# 2       1          A  20180801        3  Chevy Colorado   Automobile   1
# 3       1          A  20180801        3    Chevy Gemini   Automobile   1
# 4       1          A  20180801        3             WND       Phones   2
#
#   Sales Modifier
# 0   499        0
# 1   499        0
# 2   799        0
# 3   679        0
# 4     0        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12811321 entries, 0 to 12811320
# Data columns (total 9 columns):
# StoreID         object
# StoreGroup      object
# PeriodID        object
# TicketID        object
# ItemName        object
# ItemCategory    object
# Qty             object
# Sales           object
# Modifier        object
# dtypes: object(9)
# memory usage: 879.7+ MB

# %%
df.loc[df.isna().any(axis=1),:]
# Out:
# Empty DataFrame
# Columns: [StoreID, StoreGroup, PeriodID, TicketID, ItemName, ItemCategory, Qty, Sales, Modifier]
# Index: []

# %%
df.describe(include='all')
# Out:
#          StoreID StoreGroup  PeriodID  TicketID  ItemName ItemCategory  \
# count   12811321   12811321  12811321  12811321  12811321     12811321
# unique        90          7       365       498       397            7
# top          202          F  20190302        32     Apple   Automobile
# freq      298687    2053989     54210    100581   1313144      5724853
#
#              Qty     Sales  Modifier
# count   12811321  12811321  12811321
# unique        91      1203         2
# top            1         0         0
# freq    10850445   1851939  10959386

# %%
df.StoreGroup.unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F', 'G'], dtype=object)

# %%
df1 = df[df.StoreID =='1']

# %%
df1.describe(include='all')
# Out:
#        StoreID StoreGroup  PeriodID TicketID ItemName ItemCategory    Qty  \
# count    98675      98675     98675    98675    98675        98675  98675
# unique       1          1       339      249      274            7     11
# top          1          A  20190330       36    Apple   Automobile      1
# freq     98675      98675       898     1080    13731        46563  83046
#
#         Sales Modifier
# count   98675    98675
# unique    317        2
# top       199        0
# freq    13458    87394

# %%
df1.ItemName.unique()
# Out:
# array(['Chevy Ajax', 'Chevy Spark', 'Chevy Colorado', 'Chevy Gemini',
#        'WND', 'Luxury Package', 'Apple', 'Ford Expedition',
#        'Bose Speakers', 'Chevy Cavalier', 'Chevy Nova',
#        'Ford Quadricycle', 'Rear Spoiler', 'Samsung', 'Ford Focus',
#        'Chrysler 300', 'Chrysler Prowler', 'Vehicle Cover',
#        'Premium Seat Covers', 'Spare Tire Cover', 'Toyota Tundra',
#        'Kia Sedona', 'Ford F150', 'Google', 'Chevy Cobalt', 'Ford E150',
#        'Preimum Car Wash', 'Towing Package', 'Ford Camete',
#        'French Bulldog', 'Dodge Durango', 'LG', 'Dodge Stratus',
#        'Chevy Caprice', 'Allview', 'Ford Taurus', 'Lincoln 2010',
#        'Chevy 210', 'Apartment', 'Merida', 'Single Family (Detached)',
#        'Golden Retriever', 'Chrysler Fifth Avenue', 'Chrysler Newport',
#        'Ford Five Hundred', 'Alan', 'Amazon', 'Microsoft', 'Townhome',
#        'Chevy TrailBlazer', 'Toyota 4Runner', 'Ford Crown Victoria',
#        'Cannondale', 'Ford Explorer Sport-Trac', 'Car Sales Decal',
#        'Ford Edge', 'Chevy Lanos', 'Toyota Tacoma', 'Toyota Prius',
#        'Chevy Camaro', 'Ford Escort', 'Poodle', 'Chevy Monte Carlo',
#        'Sport Package', 'Blackberry', 'Chevy Chevelle', 'Ford Kuga',
#        'Ford Fusion', 'Kia Telluride', 'Highspeed Charger',
#        'Dodge RAM 2500', 'Febreeze Spray', 'Kia Rio', 'Condominium',
#        'Ford E250', 'Saturn ION', 'Chevy Tahoe', 'Dodge Omni',
#        'Worksman Cycles', 'Dodge Olara', 'Archos', 'Chevy Blazer',
#        'Backup Camera', 'Ford Model B', 'Ford Flex', 'Ford Explorer',
#        'Chevy Traverse', 'Boxer', 'Ford Abeille', 'Ford Eifel',
#        'Ford Custom 500', 'Fix a Flat', 'Ford F250', 'Tiny', 'Bungalow',
#        'Co-op', 'Benq-Siemens', 'Navigation System', 'Toyota Corolla',
#        'Chevy Beretta', 'Ford Crestline', 'Dodge Kingsway',
#        'Luggage Hauler', 'Wheelchair Ramp', 'Radar Detector', 'NEC',
#        'Chrysler Sebring', 'Cooler', 'Ford Bronco', 'Toyota Crown',
#        'Dodge 330', 'Pomeranian', 'Ford Aspire', 'Cottage', 'Ford GT40',
#        'Dash Camera', 'Chevy Greenbrier', 'Halogen Lights', 'Kia Picanto',
#        'Toyota Century', 'Jamis', 'OBD2 Scanner', 'Nylon Seat Covers',
#        'Chrysler Town and Country', 'BMC', 'AT&T', 'Chrysler Cordoba',
#        'Carriage/Coach', 'Chevy Viking', 'Ford B-Max', 'Sony', 'Marin',
#        'Chevy G506', 'Dodge Meadowbrook', 'Ford Transcontinental',
#        'Chevy Viva', 'Ford Model AC', 'Ultramarine', 'Ranch-Style',
#        'Chevy Standard', 'Lincoln Continental', 'Light Covers',
#        'GPS Unit', 'Leather Cleaner', 'Tinted Windows',
#        'Solor Powered Vent', 'Parking Sensors', 'Fuji',
#        'Chevy Constantia', 'Fish for Trailer Hitch', 'Lincoln MKX',
#        'Dodge RAM 3500', 'Safety Hammer', 'In-Law Suite', 'Chevy Sonic',
#        'Shetland Sheepdog', 'Dodge Viper', 'Chrysler Aspen',
#        'Fire Extinguisher', 'Bike Hauler', 'Smart Dirving Assistant',
#        'Built in Phone', 'Ford Probe', 'Inflatable Car Jack',
#        '600W Power Inverter', 'Multi-Family', 'Ford Contour',
#        'Toyota Voxy', 'Roll Bar', 'Emergency Roadside Kit', 'Kia K4',
#        'Kia Optima', 'Roll Cage', 'Kia Stinger', 'Chrysler Royal',
#        'Dodge Intrepid', 'German Pointer', 'Ford Super Deluxe',
#        'Chevy Lee', 'Chevy Forester', 'Newfoundland', 'Ford Laser',
#        'Ford Thunderbird', 'Chevy Impala', 'Ford Festiva',
#        'Metallic Blue', 'Keychain', 'Ford Escape', 'Ford Custom Deluxe',
#        'Ford F-550', 'Ford Ranch Wagon', 'Chevy HHR', 'Map Holder',
#        'Blackview', 'Chevy Van', 'Chalet', 'Ford Endeavor', 'Amoi',
#        'Ochre', 'Ford Lobo', 'Jumper Cables', 'First Aid Kit',
#        'Toyota Fortuner', 'Ford Model 69A/GGA', 'Chevy Corvair',
#        'Ford Model 4-46', 'Dodge Lancer', 'Ford SVT Raptor', 'Asus',
#        'Chevy Delray', '400W Power Inverter', 'Desert sand', 'Cabin',
#        'Greater Swiss Mountain Dog', 'Chrysler Crossfire', 'Ford GTX1',
#        'Dodge 400', 'Toyota Porte', 'Chrysler Saratoga', 'Chevy Uplander',
#        'Chevy Vega', 'Ford Telstar', 'Chevy C/K', 'Toyota Land Cruiser',
#        'Dodge Aries', 'Ford Model C', 'Suction Grip', 'Saturn Sky',
#        'Regular Floor Mats', 'Australian Shepherd', 'Chevy Mercury',
#        'Felt', 'Chrysler Sunbeem', 'Tan', 'Crimson', 'Bobble Head',
#        'Ford XL', 'Periwinkle', 'Chevy Astro', 'Ford Model 73/77',
#        'Chrysler Airstream', 'Ford Del Rey', 'Chevy Cameo',
#        'Seatbelt Cutter', 'Pillows', 'Chevy Onix', 'Chevy Lakewood',
#        'Chevy Celta', 'Trek', 'German Shepherd', 'Toyota Premio',
#        'Toyota Isis', 'Ford Model 11A/1GA', 'CD Changer', 'Ford GT', 'BQ',
#        'Celkon', 'Mansion', 'Bronze', 'Benq', 'Rear View Mirror Ball',
#        'Vent Clip on Air Freshener', 'Dodge Eight', 'Chevy A-20',
#        'CD Player', 'Ford Tempo', 'Ford Model BB', 'Dachshund',
#        'Chevy Silverado', 'Rolling Pin', 'Socket Set', 'Chevy Avalanche',
#        'Chevy Optra Wagon', 'Ford Model 8-46'], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98675 entries, 0 to 98674
# Data columns (total 9 columns):
# StoreID         98675 non-null object
# StoreGroup      98675 non-null object
# PeriodID        98675 non-null object
# TicketID        98675 non-null object
# ItemName        98675 non-null object
# ItemCategory    98675 non-null object
# Qty             98675 non-null object
# Sales           98675 non-null object
# Modifier        98675 non-null object
# dtypes: object(9)
# memory usage: 7.5+ MB

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.StoreGroup.unique()
# Out:
# array(['A'], dtype=object)

# %%
#df1.ItemName.unique()
df1.ItemCategory.unique()
# Out:
# array(['Automobile', 'Phones', 'Accessories', 'Dogs', 'Homes', 'Bicycle',
#        'Color'], dtype=object)

# %%
df1.describe(include='all')
# Out:
#        StoreID StoreGroup  PeriodID TicketID ItemName ItemCategory    Qty  \
# count    98675      98675     98675    98675    98675        98675  98675
# unique       1          1       339      249      274            7     11
# top          1          A  20190330       36    Apple   Automobile      1
# freq     98675      98675       898     1080    13731        46563  83046
#
#         Sales Modifier
# count   98675    98675
# unique    317        2
# top       199        0
# freq    13458    87394

# %%
df1['ItemName'] = df1['ItemName'].str.replace(' ','-')
df1.head()
# Out:
# /Users/Sudeep/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#   StoreID StoreGroup  PeriodID TicketID        ItemName ItemCategory Qty  \
# 0       1          A  20180801        1      Chevy-Ajax   Automobile   1
# 1       1          A  20180801        2     Chevy-Spark   Automobile   1
# 2       1          A  20180801        3  Chevy-Colorado   Automobile   1
# 3       1          A  20180801        3    Chevy-Gemini   Automobile   1
# 4       1          A  20180801        3             WND       Phones   2
#
#   Sales Modifier
# 0   499        0
# 1   499        0
# 2   799        0
# 3   679        0
# 4     0        1

# %%
df1.ItemName.unique()
# Out:
# array(['Chevy-Ajax', 'Chevy-Spark', 'Chevy-Colorado', 'Chevy-Gemini',
#        'WND', 'Luxury-Package', 'Apple', 'Ford-Expedition',
#        'Bose-Speakers', 'Chevy-Cavalier', 'Chevy-Nova',
#        'Ford-Quadricycle', 'Rear-Spoiler', 'Samsung', 'Ford-Focus',
#        'Chrysler-300', 'Chrysler-Prowler', 'Vehicle-Cover',
#        'Premium-Seat-Covers', 'Spare-Tire-Cover', 'Toyota-Tundra',
#        'Kia-Sedona', 'Ford-F150', 'Google', 'Chevy-Cobalt', 'Ford-E150',
#        'Preimum-Car-Wash', 'Towing-Package', 'Ford-Camete',
#        'French-Bulldog', 'Dodge-Durango', 'LG', 'Dodge-Stratus',
#        'Chevy-Caprice', 'Allview', 'Ford-Taurus', 'Lincoln-2010',
#        'Chevy-210', 'Apartment', 'Merida', 'Single-Family-(Detached)',
#        'Golden-Retriever', 'Chrysler-Fifth-Avenue', 'Chrysler-Newport',
#        'Ford-Five-Hundred', 'Alan', 'Amazon', 'Microsoft', 'Townhome',
#        'Chevy-TrailBlazer', 'Toyota-4Runner', 'Ford-Crown-Victoria',
#        'Cannondale', 'Ford-Explorer-Sport-Trac', 'Car-Sales-Decal',
#        'Ford-Edge', 'Chevy-Lanos', 'Toyota-Tacoma', 'Toyota-Prius',
#        'Chevy-Camaro', 'Ford-Escort', 'Poodle', 'Chevy-Monte-Carlo',
#        'Sport-Package', 'Blackberry', 'Chevy-Chevelle', 'Ford-Kuga',
#        'Ford-Fusion', 'Kia-Telluride', 'Highspeed-Charger',
#        'Dodge-RAM-2500', 'Febreeze-Spray', 'Kia-Rio', 'Condominium',
#        'Ford-E250', 'Saturn-ION', 'Chevy-Tahoe', 'Dodge-Omni',
#        'Worksman-Cycles', 'Dodge-Olara', 'Archos', 'Chevy-Blazer',
#        'Backup-Camera', 'Ford-Model-B', 'Ford-Flex', 'Ford-Explorer',
#        'Chevy-Traverse', 'Boxer', 'Ford-Abeille', 'Ford-Eifel',
#        'Ford-Custom-500', 'Fix-a-Flat', 'Ford-F250', 'Tiny', 'Bungalow',
#        'Co-op', 'Benq-Siemens', 'Navigation-System', 'Toyota-Corolla',
#        'Chevy-Beretta', 'Ford-Crestline', 'Dodge-Kingsway',
#        'Luggage-Hauler', 'Wheelchair-Ramp', 'Radar-Detector', 'NEC',
#        'Chrysler-Sebring', 'Cooler', 'Ford-Bronco', 'Toyota-Crown',
#        'Dodge-330', 'Pomeranian', 'Ford-Aspire', 'Cottage', 'Ford-GT40',
#        'Dash-Camera', 'Chevy-Greenbrier', 'Halogen-Lights', 'Kia-Picanto',
#        'Toyota-Century', 'Jamis', 'OBD2-Scanner', 'Nylon-Seat-Covers',
#        'Chrysler-Town-and-Country', 'BMC', 'AT&T', 'Chrysler-Cordoba',
#        'Carriage/Coach', 'Chevy-Viking', 'Ford-B-Max', 'Sony', 'Marin',
#        'Chevy-G506', 'Dodge-Meadowbrook', 'Ford-Transcontinental',
#        'Chevy-Viva', 'Ford-Model-AC', 'Ultramarine', 'Ranch-Style',
#        'Chevy-Standard', 'Lincoln-Continental', 'Light-Covers',
#        'GPS-Unit', 'Leather-Cleaner', 'Tinted-Windows',
#        'Solor-Powered-Vent', 'Parking-Sensors', 'Fuji',
#        'Chevy-Constantia', 'Fish-for-Trailer-Hitch', 'Lincoln-MKX',
#        'Dodge-RAM-3500', 'Safety-Hammer', 'In-Law-Suite', 'Chevy-Sonic',
#        'Shetland-Sheepdog', 'Dodge-Viper', 'Chrysler-Aspen',
#        'Fire-Extinguisher', 'Bike-Hauler', 'Smart-Dirving-Assistant',
#        'Built-in-Phone', 'Ford-Probe', 'Inflatable-Car-Jack',
#        '600W-Power-Inverter', 'Multi-Family', 'Ford-Contour',
#        'Toyota-Voxy', 'Roll-Bar', 'Emergency-Roadside-Kit', 'Kia-K4',
#        'Kia-Optima', 'Roll-Cage', 'Kia-Stinger', 'Chrysler-Royal',
#        'Dodge-Intrepid', 'German-Pointer', 'Ford-Super-Deluxe',
#        'Chevy-Lee', 'Chevy-Forester', 'Newfoundland', 'Ford-Laser',
#        'Ford-Thunderbird', 'Chevy-Impala', 'Ford-Festiva',
#        'Metallic-Blue', 'Keychain', 'Ford-Escape', 'Ford-Custom-Deluxe',
#        'Ford-F-550', 'Ford-Ranch-Wagon', 'Chevy-HHR', 'Map-Holder',
#        'Blackview', 'Chevy-Van', 'Chalet', 'Ford-Endeavor', 'Amoi',
#        'Ochre', 'Ford-Lobo', 'Jumper-Cables', 'First-Aid-Kit',
#        'Toyota-Fortuner', 'Ford-Model-69A/GGA', 'Chevy-Corvair',
#        'Ford-Model-4-46', 'Dodge-Lancer', 'Ford-SVT-Raptor', 'Asus',
#        'Chevy-Delray', '400W-Power-Inverter', 'Desert-sand', 'Cabin',
#        'Greater-Swiss-Mountain-Dog', 'Chrysler-Crossfire', 'Ford-GTX1',
#        'Dodge-400', 'Toyota-Porte', 'Chrysler-Saratoga', 'Chevy-Uplander',
#        'Chevy-Vega', 'Ford-Telstar', 'Chevy-C/K', 'Toyota-Land-Cruiser',
#        'Dodge-Aries', 'Ford-Model-C', 'Suction-Grip', 'Saturn-Sky',
#        'Regular-Floor-Mats', 'Australian-Shepherd', 'Chevy-Mercury',
#        'Felt', 'Chrysler-Sunbeem', 'Tan', 'Crimson', 'Bobble-Head',
#        'Ford-XL', 'Periwinkle', 'Chevy-Astro', 'Ford-Model-73/77',
#        'Chrysler-Airstream', 'Ford-Del-Rey', 'Chevy-Cameo',
#        'Seatbelt-Cutter', 'Pillows', 'Chevy-Onix', 'Chevy-Lakewood',
#        'Chevy-Celta', 'Trek', 'German-Shepherd', 'Toyota-Premio',
#        'Toyota-Isis', 'Ford-Model-11A/1GA', 'CD-Changer', 'Ford-GT', 'BQ',
#        'Celkon', 'Mansion', 'Bronze', 'Benq', 'Rear-View-Mirror-Ball',
#        'Vent-Clip-on-Air-Freshener', 'Dodge-Eight', 'Chevy-A-20',
#        'CD-Player', 'Ford-Tempo', 'Ford-Model-BB', 'Dachshund',
#        'Chevy-Silverado', 'Rolling-Pin', 'Socket-Set', 'Chevy-Avalanche',
#        'Chevy-Optra-Wagon', 'Ford-Model-8-46'], dtype=object)

# %%
plt.plot(df1.ItemCategory, df1.Sales)
plt.show()

# %%
df2 = df1[df1.PeriodID <= '20181231']

# %%
df3 = df1[df1.PeriodID >= '20190101']

# %%
df2.info()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42859 entries, 0 to 42858
# Data columns (total 9 columns):
# StoreID         42859 non-null object
# StoreGroup      42859 non-null object
# PeriodID        42859 non-null object
# TicketID        42859 non-null object
# ItemName        42859 non-null object
# ItemCategory    42859 non-null object
# Qty             42859 non-null object
# Sales           42859 non-null object
# Modifier        42859 non-null object
# dtypes: object(9)
# memory usage: 3.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55816 entries, 42859 to 98674
# Data columns (total 9 columns):
# StoreID         55816 non-null object
# StoreGroup      55816 non-null object
# PeriodID        55816 non-null object
# TicketID        55816 non-null object
# ItemName        55816 non-null object
# ItemCategory    55816 non-null object
# Qty             55816 non-null object
# Sales           55816 non-null object
# Modifier        55816 non-null object
# dtypes: object(9)
# memory usage: 4.3+ MB

# %%
df2.head()
# Out:
#   StoreID StoreGroup  PeriodID TicketID        ItemName ItemCategory Qty  \
# 0       1          A  20180801        1      Chevy-Ajax   Automobile   1
# 1       1          A  20180801        2     Chevy-Spark   Automobile   1
# 2       1          A  20180801        3  Chevy-Colorado   Automobile   1
# 3       1          A  20180801        3    Chevy-Gemini   Automobile   1
# 4       1          A  20180801        3             WND       Phones   2
#
#   Sales Modifier
# 0   499        0
# 1   499        0
# 2   799        0
# 3   679        0
# 4     0        1

# %%
df3.StoreID.iloc[0]
# Out:
# '1'

# %%
min(df2.Sales)
# Out:
#      StoreID StoreGroup  PeriodID TicketID    ItemName ItemCategory Qty  \
# 2251       1          A  20180809       33  Ford-Focus   Automobile   2
# 2252       1          A  20180809       33      Google       Phones   1
#
#       Sales Modifier
# 2251  -1698        0
# 2252   -199        0

# %%
negativeVal = df2[df2.Sales < '0']
negativeVal
# Out:
#      StoreID StoreGroup  PeriodID TicketID    ItemName ItemCategory Qty  \
# 2251       1          A  20180809       33  Ford-Focus   Automobile   2
# 2252       1          A  20180809       33      Google       Phones   1
#
#       Sales Modifier
# 2251  -1698        0
# 2252   -199        0

# %%
df2['Sales'] = df2['Sales'].str.replace('-','')
df2.head()
# Out:
#    StoreID StoreGroup  PeriodID  TicketID        ItemName ItemCategory  Qty  \
# 0        1          A  20180801         1      Chevy-Ajax   Automobile    1
# 1        1          A  20180801         2     Chevy-Spark   Automobile    1
# 2        1          A  20180801         3  Chevy-Colorado   Automobile    1
# 3        1          A  20180801         3    Chevy-Gemini   Automobile    1
# 4        1          A  20180801         3             WND       Phones    2
#
#    Sales  Modifier
# 0    499         0
# 1    499         0
# 2    799         0
# 3    679         0
# 4      0         1

# %%
negativeVal = df2[df2.Sales < '0']
negativeVal
# Out:
# Empty DataFrame
# Columns: [StoreID, StoreGroup, PeriodID, TicketID, ItemName, ItemCategory, Qty, Sales, Modifier]
# Index: []

# %%
df2['StoreID'] = df2['StoreID'].astype(str).astype(int)
#df2['PeriodID'] = df2['PeriodID'].astype(str).astype(int)
df2['TicketID'] = df2['TicketID'].astype(str).astype(int)
df2['Qty'] = df2['Qty'].astype(str).astype(int)
df2['Sales'] = df2['Sales'].astype(str).astype(int)
df2['Modifier'] = df2['Modifier'].astype(str).astype(int)
#df2['StoreGroup'] = df2['StoreGroup'].astype('str')
#df2['ItemName'] = df2['ItemName'].astype('str')
#df2['ItemCategory'] = df2['ItemCategory'].astype('str')
df2.info()
# Out:
# /Users/Sudeep/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/Sudeep/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Sudeep/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/Sudeep/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42859 entries, 0 to 42858
# Data columns (total 9 columns):
# StoreID         42859 non-null int64
# StoreGroup      42859 non-null object
# PeriodID        42859 non-null object
# TicketID        42859 non-null int64
# ItemName        42859 non-null object
# ItemCategory    42859 non-null object
# Qty             42859 non-null int64
# Sales           42859 non-null int64
# Modifier        42859 non-null int64
# dtypes: int64(5), object(4)
# memory usage: 3.3+ MB
# /Users/Sudeep/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def var_scatter(df2, var):
    ax=None
    if ax is None:
        _, ax = plt.subplots(figsize=(8, 6))
    df2.plot.scatter(x=var , y="Qty", alpha=0.35, s=1.5, ax=ax)

    return ax

var_scatter(df2, "TicketID");
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
plt.plot(df2.PeriodID, df2.Sales)
plt.show()

# %%
plt.plot(df2.TicketID,df2.Qty * 10)
plt.plot(df2.TicketID,df2.Sales/10**2)
plt.legend(['Qty', 'Sales'])
plt.xlabel('Ticket ID')
plt.ylabel('Units')
plt.show()

# %%
plt.plot(df2.TicketID,df2.Qty / df2.Qty.iloc[0] * 100)
plt.plot(df2.TicketID,df2.Sales / df2.Sales.iloc[0]*100)
plt.legend(['Qty', 'Sales'])
plt.xlabel('Ticket ID')
plt.ylabel('Growth in Units(First Ticket = 100)')
plt.show()

# %%
maxSalesValue = df2[df2.Sales > 5000]
maxSalesValue
# Out:
#        StoreID StoreGroup  PeriodID  TicketID  ItemName ItemCategory  Qty  \
# 32908        1          A  20181128        57  Keychain  Accessories    1
# 39175        1          A  20181221        32  Keychain  Accessories    1
# 39176        1          A  20181221        33  Keychain  Accessories    1
#
#        Sales  Modifier
# 32908  50000         0
# 39175  10000         0
# 39176  10000         0

# %%
itemKC = df2[df2.ItemName == 'Keychain']
itemKC
# Out:
#        StoreID StoreGroup  PeriodID  TicketID  ItemName ItemCategory  Qty  \
# 4050         1          A  20180817        24  Keychain  Accessories    1
# 26243        1          A  20181105        25  Keychain  Accessories    1
# 30952        1          A  20181122        34  Keychain  Accessories    1
# 31660        1          A  20181124        11  Keychain  Accessories    1
# 32908        1          A  20181128        57  Keychain  Accessories    1
# 34370        1          A  20181203        23  Keychain  Accessories    1
# 35228        1          A  20181207        28  Keychain  Accessories    2
# 36708        1          A  20181212        22  Keychain  Accessories    1
# 39145        1          A  20181221        20  Keychain  Accessories    1
# 39172        1          A  20181221        29  Keychain  Accessories    1
# 39173        1          A  20181221        30  Keychain  Accessories    1
# 39175        1          A  20181221        32  Keychain  Accessories    1
# 39176        1          A  20181221        33  Keychain  Accessories    1
# 39206        1          A  20181221        40  Keychain  Accessories    1
# 39207        1          A  20181221        41  Keychain  Accessories    1
# 39827        1          A  20181223         9  Keychain  Accessories    1
# 40285        1          A  20181224        30  Keychain  Accessories    1
# 40319        1          A  20181224        41  Keychain  Accessories    1
# 40329        1          A  20181224        46  Keychain  Accessories    3
# 40561        1          A  20181225         5  Keychain  Accessories    1
# 41896        1          A  20181229        10  Keychain  Accessories    1
#
#        Sales  Modifier
# 4050    4000         0
# 26243   2500         0
# 30952   2500         0
# 31660   3000         0
# 32908  50000         0
# 34370   1000         0
# 35228   2000         0
# 36708   3000         0
# 39145    500         0
# 39172   5000         0
# 39173   2500         0
# 39175  10000         0
# 39176  10000         0
# 39206   2000         0
# 39207   2000         0
# 39827   2000         0
# 40285   5000         0
# 40319   2500         0
# 40329   5000         0
# 40561   5000         0
# 41896   2500         0

# %%
maxQtyValue = df2[df2.Qty > 5]
maxQtyValue
# Out:
#        StoreID StoreGroup  PeriodID  TicketID         ItemName ItemCategory  \
# 4556         1          A  20180818       114            Apple       Phones
# 6772         1          A  20180826       106              WND       Phones
# 7998         1          A  20180901        56           Google       Phones
# 8919         1          A  20180903        79              WND       Phones
# 11622        1          A  20180914        54              WND       Phones
# 12140        1          A  20180915       114           Google       Phones
# 12621        1          A  20180916       106               LG       Phones
# 13451        1          A  20180921        32              WND       Phones
# 16672        1          A  20181003        32           Google       Phones
# 27861        1          A  20181111        27              WND       Phones
# 28186        1          A  20181111       117              WND       Phones
# 29841        1          A  20181118        40           Google       Phones
# 31101        1          A  20181122        75              WND       Phones
# 35100        1          A  20181206        52              WND       Phones
# 40549        1          A  20181224       110           Google       Phones
# 40604        1          A  20181225        21    Sport-Package  Accessories
# 40605        1          A  20181225        21  Car-Sales-Decal        Color
# 42147        1          A  20181229        89              WND       Phones
#
#        Qty  Sales  Modifier
# 4556     8   1512         0
# 6772     6      0         1
# 7998     7   1393         0
# 8919     7      0         1
# 11622    6      0         1
# 12140    6   1194         0
# 12621    6   1494         0
# 13451    6      0         1
# 16672    6   1194         0
# 27861    6      0         1
# 28186    7      0         1
# 29841    6   1194         0
# 31101    7      0         1
# 35100   11      0         1
# 40549    6   1194         0
# 40604    8    712         0
# 40605    7      0         1
# 42147    6      0         1

# %%
zeroSales = df2[df2.Sales == 0]
zeroSales.describe(include='all')
# Out:
#         StoreID StoreGroup  PeriodID     TicketID ItemName ItemCategory  \
# count    4667.0       4667      4667  4667.000000     4667         4667
# unique      NaN          1       153          NaN        5            3
# top         NaN          A  20181118          NaN      WND       Phones
# freq        NaN       4667        64          NaN     3850         4109
# mean        1.0        NaN       NaN    53.760874      NaN          NaN
# std         0.0        NaN       NaN    33.177054      NaN          NaN
# min         1.0        NaN       NaN     1.000000      NaN          NaN
# 25%         1.0        NaN       NaN    26.000000      NaN          NaN
# 50%         1.0        NaN       NaN    50.000000      NaN          NaN
# 75%         1.0        NaN       NaN    76.000000      NaN          NaN
# max         1.0        NaN       NaN   166.000000      NaN          NaN
#
#                 Qty   Sales  Modifier
# count   4667.000000  4667.0    4667.0
# unique          NaN     NaN       NaN
# top             NaN     NaN       NaN
# freq            NaN     NaN       NaN
# mean       1.367474     0.0       1.0
# std        0.688648     0.0       0.0
# min        1.000000     0.0       1.0
# 25%        1.000000     0.0       1.0
# 50%        1.000000     0.0       1.0
# 75%        2.000000     0.0       1.0
# max       11.000000     0.0       1.0
